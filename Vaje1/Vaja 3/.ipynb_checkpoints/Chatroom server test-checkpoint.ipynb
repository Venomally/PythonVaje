# %%
import socket
import select

HEADER_LENGTH = 10

IP = "0.0.0.0"
PORT = 1232

# Naredimo socket - TCP
server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)

# SOL_ - socket option level. S tem SO_REUSEADDR postavimo na 1, address lahko uporabljamo večkrat
server_socket.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)

# Bind
server_socket.bind((IP, PORT))

# Socket nastavimo na listen

server_socket.listen()

# Seznam vseh socketov
sockets_list = [server_socket]

# Seznam vseh uporabnikov
clients = {}

print(f'Listening for connections on {IP}:{PORT}...')

# Sprejme sporočilo
def receive_message(client_socket):

    print('TUKAJ SMO')
    # Preberi header, ki je vedno enako dolg (pove dolžino sporočila)
    message_header = client_socket.recv(HEADER_LENGTH)


    # Napaka - ni sporočila
    if not len(message_header):
        return False

    # Preberi dolžino sporočila
    message_length = int(message_header)

    message = client_socket.recv(message_length)

    # Vrnemo objekt, ki vsebuje 'header' in samo sporočilo ('data')
    print('sprejeli smo')
    print(message)
    return {'header' : message_header, 'data' : message}

while True:
    # Z naslednjo vrstico čakamo na dogodek. Dobimo read_sockets seznam socketov, kjer se je nekaj zgodilo.
    read_sockets, _, _ = select.select(sockets_list, [], sockets_list) # Blokira, dokler nečesa ne sprejme

    # Iteriramo čez sockete, kjer se je kaj zgodilo
    for active_socket in read_sockets:
        
        # if "imamo novega uporabnika":
        if active_socket == server_socket:

            # Sprejmimo povezavo (funkcija accept()), imamo nov socket client_socket za novega uporabnika.
            new_socket, client_address = server_socket.accept()
            # Po povezavi uporanik sporoči Uporabniško ime
            
            user = receive_message(new_socket)

            # Če je uporabnik prekinil povezavo, ni poslal imena
            if user is False:
                continue

            # Sicer socket dodamo na seznam socketov
            
            sockets_list.append(new_socket)

            # In shranimo uporabniško ime v dictionary
            clients[new_socket] = user

            # Print
            print('Sprejeta povezava od {}:{}, uporabniško ime: {}'.format(*client_address, user['data'].decode('utf-8')))

        # if "nimamo novega uporabnika", smo dobili sporočilo!
        else:

            # Sprejmemo sporočilo
            
            message = receive_message(active_socket)

            # If False: v tem primeru je uporabnik zaprl povezavo, za njim "počistimo"
            if message is False:
                print('Closed connection from: {}'.format(clients[notified_socket]['data'].decode('utf-8')))

                # Odstranimo socket (list.remove)
                
                sockets_list.remove(active_socket)

                # Odstranimo uporabniško ime (del iz dictionary)
                del clients[active_socket]

                continue

            # Poiščemo uporabniško ime preko socketa, ki je aktiven
            
            user = clients[active_socket]

            print(f'Prejeto sporočilo od {user["data"].decode("utf-8")}: {message["data"].decode("utf-8")}')

            # Sporočilo pošljemo vsem uporabnikom, razen...
            for client_socket in clients:

                # Razen tistemu, ki je sporočilo poslal
                if client_socket != active_socket:
                    
                    # Uporabnikom pošljemo sporočilo in ime uporabnika, ki ga je poslal. Oblika sporočila: username header, username, sporočilo header, sporočilo
                    client_socket.send(user['header'] + user['data'] + message['header'] + message['data'])
# Out:
# Listening for connections on 0.0.0.0:1232...
# TUKAJ SMO
# sprejeli smo
# b'Martin'
# Sprejeta povezava od 127.0.0.1:51738, uporabniško ime: Martin
# TUKAJ SMO
# sprejeli smo
# b'a'
# Prejeto sporočilo od Martin: a
# TUKAJ SMO
# sprejeli smo
# b's'
# Prejeto sporočilo od Martin: s
# TUKAJ SMO
# sprejeli smo
# b'Bre\xc5\xa1ar'
# Sprejeta povezava od 127.0.0.1:51739, uporabniško ime: Brešar
# TUKAJ SMO
# sprejeli smo
# b'Zdravo'
# Prejeto sporočilo od Brešar: Zdravo
# TUKAJ SMO
# sprejeli smo
# b'hah'
# Prejeto sporočilo od Brešar: hah
# TUKAJ SMO
# sprejeli smo
# b'a'
# Prejeto sporočilo od Martin: a
# TUKAJ SMO
# sprejeli smo
# b'a'
# Prejeto sporočilo od Martin: a
# TUKAJ SMO
# sprejeli smo
# b'a'
# Prejeto sporočilo od Martin: a
# TUKAJ SMO
# sprejeli smo
# b'a'
# Prejeto sporočilo od Martin: a
# TUKAJ SMO
# sprejeli smo
# b'M'
# Prejeto sporočilo od Brešar: M
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-01771f2fca84> in <module>
#      52 while True:
#      53     # Z naslednjo vrstico čakamo na dogodek. Dobimo read_sockets seznam socketov, kjer se je nekaj zgodilo.
# ---> 54     read_sockets, _, _ = select.select(sockets_list, [], sockets_list) # Blokira, dokler nečesa ne sprejme
#      55
#      56     # Iteriramo čez sockete, kjer se je kaj zgodilo
#
# KeyboardInterrupt:

# %%
import socket
import select

HEADER_LENGTH = 10

IP = "0.0.0.0"
PORT = 1234

# Naredimo socket - TCP
server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)

# SOL_ - socket option level
# S tem SO_REUSEADDR postavimo na 1, address lahko uporabljamo večkrat
server_socket.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)

# Bind
server_socket.bind((IP, PORT))

# Socket nastavimo na listen
server_socket.listen()

# Seznam vseh socketov
sockets_list = [server_socket]

# Seznam vseh uporabnikov
clients = {}

# Izpišemo IP:PORT 
print(f'Listening for connections on {IP}:{PORT}...')

# Sprejme sporočilo
def receive_message(client_socket):

    try:
        # Preberi header, ki je vedno enako dolg (pove dolžino sporočila)
        message_header = client_socket.recv(HEADER_LENGTH)
        
        # Napaka - ni sporočila
        if not len(message_header):
            return False

        # Preberi dolžino sporočila
        message_length = int(message_header.decode('utf-8').strip())

        # Vrnemo objekt, ki vsebuje header in samo sporočilo ('data')
        return {'header': message_header, 'data': client_socket.recv(message_length)}
    except:
        return False # Napaka

while True:
    # Z naslednjo vrstico čakamo na dogodek. Dobimo read_sockets seznam socketov, kjer se je nekaj zgodilo.
    read_sockets, _, _ = select.select(sockets_list, [], sockets_list) # Blokira, dokler nečesa ne sprejme

    # Iteriramo čez sockete, kjer se je kaj zgodilo
    for notified_socket in read_sockets:
        
        # if "imamo novega uporabnika":
        if notified_socket == server_socket:

            # Sprejmimo povezavo, imamo nov socket client_socket za novega uporabnika.
            client_socket, client_address = server_socket.accept()

            # Po povezavi uporanik sporoči Uporabniško ime
            user = receive_message(client_socket)

            # Če je uporabnik prekinil povezavo, ni poslal imena
            if user is False:
                continue

            # Sicer socket dodamo na seznam socketov
            sockets_list.append(client_socket)

            # In shranimo uporabniško ime
            clients[client_socket] = user
            print('Sprejeta povezava od {}:{}, uporabniško ime: {}'.format(*client_address, user['data'].decode('utf-8')))

        # if "nimamo novega uporabnika", smo dobili sporočilo!
        else:

            # Sprejmemo sporočilo
            message = receive_message(notified_socket)

            # If False: v tem primeru je uporabnik zaprl povezavo, za njim "počistimo"
            if message is False:
                print('Closed connection from: {}'.format(clients[notified_socket]['data'].decode('utf-8')))

                # Odstranimo socket
                sockets_list.remove(notified_socket)

                # Odstranimo uporabniško ime
                del clients[notified_socket]

                continue

            # Poiščemo uporabniško ime preko socketa, ki je aktiven
            user = clients[notified_socket]

            print(f'Prejeto sporočilo od {user["data"].decode("utf-8")}: {message["data"].decode("utf-8")}')

            # Sporočilo pošljemo vsem uporabnikom, razen...
            for client_socket in clients:

                # Razen tistemu, ki je sporočilo poslal
                if client_socket != notified_socket:

                    # Uporabnikom pošljemo sporočilo in ime uporabnika, ki ga je poslal
                    client_socket.send(user['header'] + user['data'] + message['header'] + message['data'])
# Out:
# Listening for connections on 0.0.0.0:1234...
# Sprejeta povezava od 127.0.0.1:51643, uporabniško ime: Martin
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-4353706d00a1> in <module>
#      50 while True:
#      51     # Z naslednjo vrstico čakamo na dogodek. Dobimo read_sockets seznam socketov, kjer se je nekaj zgodilo.
# ---> 52     read_sockets, _, _ = select.select(sockets_list, [], sockets_list) # Blokira, dokler nečesa ne sprejme
#      53
#      54     # Iteriramo čez sockete, kjer se je kaj zgodilo
#
# KeyboardInterrupt:
