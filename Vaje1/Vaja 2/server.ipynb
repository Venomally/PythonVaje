# %%
import socketserver
HEADER_LENGTH = 10

class handler(socketserver.BaseRequestHandler):
    def handle(self):
        header1 = self.request.recv(HEADER_LENGTH)
        message1 = self.request.recv(int(header1)).decode()
        
        header2 = self.request.recv(HEADER_LENGTH)
        message2 = self.request.recv(int(header2)).decode()
        
        print('Sporočilo 1 je {} in sporočilo 2 je {}'.format(message1, message2))
        
        if int(header1) > int(header2):
            self.request.sendall(message1.encode())
        else:
            self.request.sendall(message2.encode())
        
server = socketserver.TCPServer(('0.0.0.0',1235), handler)
server.serve_forever()
# Out:
# Sporočilo 1 je Kratko in sporočilo 2 je Dooooolgooooo
# Sporočilo 1 je Kratko?????????????????????? in sporočilo 2 je Dooooolgooooo
# Sporočilo 1 je Kratko in sporočilo 2 je Dooooolgooooo
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 20
#      17             self.request.sendall(message2.encode())
#      19 server = socketserver.TCPServer(('0.0.0.0',1235), handler)
# ---> 20 server.serve_forever()
#
# File ~/miniconda3/lib/python3.9/socketserver.py:232, in BaseServer.serve_forever(self, poll_interval)
#     229 selector.register(self, selectors.EVENT_READ)
#     231 while not self.__shutdown_request:
# --> 232     ready = selector.select(poll_interval)
#     233     # bpo-35017: shutdown() called during select(), exit immediately.
#     234     if self.__shutdown_request:
#
# File ~/miniconda3/lib/python3.9/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:
