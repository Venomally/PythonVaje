# %%
import socketserver
HEADER_LENGTH = 10

class handler(socketserver.BaseRequestHandler):
    def handle(self):
        try:
            header1 = self.request.recv(HEADER_LENGTH)
            message1 = self.request.recv(int(header1)).decode()

            header2 = self.request.recv(HEADER_LENGTH)
            message2 = self.request.recv(int(header2)).decode()

            print('Sporočilo 1 je {} in sporočilo 2 je {}'.format(message1, message2))

            if int(header1) > int(header2):
                self.request.sendall(message1.encode())
            else:
                self.request.sendall(message2.encode())
        except:
            print('Prejeto sporočilo v napačnem formatu')
            print("{}:".format(self.client_address[0]))

        
server = socketserver.TCPServer(('0.0.0.0',1236), handler)
server.serve_forever()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-c8d293cc028a> in <module>
#      23
#      24 server = socketserver.TCPServer(('0.0.0.0',1236), handler)
# ---> 25 server.serve_forever()
#
# ~/opt/anaconda3/lib/python3.8/socketserver.py in serve_forever(self, poll_interval)
#     230
#     231                 while not self.__shutdown_request:
# --> 232                     ready = selector.select(poll_interval)
#     233                     # bpo-35017: shutdown() called during select(), exit immediately.
#     234                     if self.__shutdown_request:
#
# ~/opt/anaconda3/lib/python3.8/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:
