# %%
import socketserver

class MyTCPHandler(socketserver.BaseRequestHandler):
    """ Handle naj sprejme sporočilo, in sporočilo pošlje nazaj"""
    def handle(self):
        self.data = self.request.recv(1024)
        print('Dobili smo sporočilo od: {}'.format(self.client_address[0]))
        print('Sporočilo je: {}'.format(self.data.decode()))
        self.request.sendall(self.data)


HOST, PORT = "0.0.0.0", 1234

with socketserver.TCPServer((HOST, PORT), MyTCPHandler) as server:
    server.serve_forever()
# Out:
# Dobili smo sporočilo od: 127.0.0.1
# Sporočilo je: Živjo
# Dobili smo sporočilo od: 127.0.0.1
# Sporočilo je: Živjo!
# Dobili smo sporočilo od: 127.0.0.1
# Sporočilo je: Živjo!!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-a8062b996d72> in <module>
#      13
#      14 with socketserver.TCPServer((HOST, PORT), MyTCPHandler) as server:
# ---> 15     server.serve_forever()
#
# ~/opt/anaconda3/lib/python3.8/socketserver.py in serve_forever(self, poll_interval)
#     230
#     231                 while not self.__shutdown_request:
# --> 232                     ready = selector.select(poll_interval)
#     233                     # bpo-35017: shutdown() called during select(), exit immediately.
#     234                     if self.__shutdown_request:
#
# ~/opt/anaconda3/lib/python3.8/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:
